# %%
# %run setup.ipynb
# %run ../agam-report-base/src/python/ag1k/phase2_ar1.py
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
import cartopy; print('cartopy', cartopy.__version__)
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# <style type="text/css">
# .container {
#     width: 100%;
# }
# </style>
# cartopy 0.17.0

# %%
# !conda install -c conda-forge gdal
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: /
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                -      failed
#
# UnsatisfiableError: The following specifications were found to be incompatible with a past
# explicit spec that is not an explicit spec in this operation (libstdcxx-ng):
#
#   - gdal -> libgcc-ng[version='>=7.3.0']
#   - gdal -> libstdcxx-ng[version='>=7.3.0']
#   - gdal -> numpy[version='>=1.14.6,<2.0a0']
#
# The following specifications were found to be incompatible with each other:
#
#
#
# Package xorg-renderproto conflicts for:
# xorg-libxrender==0.9.10=h516909a_1002 -> xorg-renderproto
# Package numpy conflicts for:
# bqplot==0.11.6=py_0 -> numpy[version='>=1.10.4']
# tskit==0.1.5=py36hd352d35_0 -> numpy[version='>=1.9.3,<2.0a0']
# numba==0.45.1=py36hb3f55d8_0 -> numpy[version='>=1.14.6,<2.0a0']
# pyfasta==0.5.2=py36_0 -> numpy
# msprime==0.7.3=py36heade8f8_0 -> numpy[version='>=1.14.6,<2.0a0']
# hmmlearn==0.2.1=py36h3010b51_1000 -> numpy[version='>=1.9.3,<2.0a0']
# matplotlib-venn==0.11.5=py_1 -> numpy
# fastcluster==1.1.25=py36h637b7d7_1000 -> numpy[version='>=1.9.3,<2.0a0']
# fastparquet==0.3.2=py36hc1659b7_0 -> numpy
# pytables==3.5.2=py36ha1aa75f_0 -> numpy[version='>=1.14.6,<2.0a0']
# scikit-allel==1.2.1=py36hb3f55d8_0 -> numpy[version='>=1.14.6,<2.0a0']
# scikit-learn==0.21.3=py36hcdab131_0 -> numpy[version='>=1.14.6,<2.0a0']
# matplotlib-base==3.1.1=py36he7580a8_1 -> numpy[version='>=1.14.6,<2.0a0']
# lmfit==0.9.13=pyh24bf2e0_0 -> numpy
# netcdf4==1.5.1.2=py36had58050_0 -> numpy[version='>=1.9.3,<2.0a0']
# holoviews==1.12.4=py_0 -> numpy[version='>=1.0']
# bokeh==1.3.2=py36_0 -> numpy[version='>=1.7.1']
# asteval==0.9.14=pyh24bf2e0_0 -> numpy
# uncertainties==3.1.2=py36_0 -> numpy
# h5py==2.9.0=nompi_py36hcafd542_1103 -> numpy[version='>=1.14.6,<2.0a0']
# biopython==1.74=py36h516909a_0 -> numpy
# pywavelets==1.0.3=py36hd352d35_1 -> numpy[version='>=1.9.3,<2.0a0']
# pykdtree==1.3.1=py36h3010b51_1002 -> numpy[version='>=1.9.3,<2.0a0']
# pysamstats==1.1.2=py36h84994c4_3 -> numpy
# statsmodels==0.10.1=py36hc1659b7_0 -> numpy[version='>=1.14.6,<2.0a0']
# scipy==1.3.0=py36h921218d_1 -> numpy[version='>=1.14.6,<2.0a0']
# numcodecs==0.6.3=py36hf484d3e_0 -> numpy
# dask==2.2.0=py_0 -> numpy[version='>=1.13.0']
# patsy==0.5.1=py_0 -> numpy[version='>=1.4.0']
# msgpack-numpy==0.4.4.3=py_0 -> numpy[version='>=1.9.0']
# bcolz==1.2.1=py36h637b7d7_1001 -> numpy[version='>=1.9.3,<2.0a0']
# dask-ml==1.0.0=py_0 -> numpy
# pomegranate==0.11.0=py36h9de70de_0 -> numpy[version='>=1.14.6,<2.0a0']
# shapely==1.6.4=py36hec07ddf_1006 -> numpy[version='>=1.14.6,<2.0a0']
# intake==0.5.2=py_0 -> numpy
# seaborn==0.9.0=py_1 -> numpy[version='>=1.9.3']
# cftime==1.0.3.4=py36hd352d35_1001 -> numpy[version='>=1.9.3,<2.0a0']
# xarray==0.12.3=py_0 -> numpy[version='>=1.12']
# zarr==2.3.2=py36_0 -> numpy[version='>=1.7']
# imageio==2.5.0=py36_0 -> numpy
# numexpr==2.6.9=py36h637b7d7_1000 -> numpy[version='>=1.9.3,<2.0a0']
# pyproj==1.9.6=py36h516909a_1002 -> numpy
# scikit-image==0.15.0=py36hb3f55d8_2 -> numpy[version='>=1.14.6,<2.0a0']
# cartopy==0.17.0=py36hd759880_1006 -> numpy[version='>=1.14.6,<2.0a0']
# pandas==0.25.0=py36hb3f55d8_0 -> numpy[version='>=1.14.6,<2.0a0']
# Package mock conflicts for:
# pytables==3.5.2=py36ha1aa75f_0 -> mock
# Package xorg-libxt conflicts for:
# xorg-libxpm==3.5.12=h14c3975_1002 -> xorg-libxt=1.1
# Package cftime conflicts for:
# netcdf4==1.5.1.2=py36had58050_0 -> cftime
# Package smmap2 conflicts for:
# gitdb2==2.0.5=py_0 -> smmap2
# Package traitlets conflicts for:
# jupyterhub==1.0.0=py36_0 -> traitlets[version='>=4.3.2']
# notebook==6.0.0=py36_0 -> traitlets[version='>=4.2.1']
# jupyter_client==5.3.1=py_0 -> traitlets
# bqplot==0.11.6=py_0 -> traitlets[version='>=4.3.0,<5.0']
# nbconvert==5.5.0=py_0 -> traitlets[version='>=4.2']
# ipython==7.7.0=py36h5ca1d4c_0 -> traitlets[version='>=4.2']
# nbformat==4.4.0=py_1 -> traitlets[version='>=4.1']
# qtconsole==4.5.2=py_0 -> traitlets
# traittypes==0.2.1=py_1 -> traitlets[version='>=4.2.2,<5.0']
# ipywidgets==7.5.1=py_0 -> traitlets[version='>=4.3.1,<5.0.0']
# jupyter_core==4.4.0=py_0 -> traitlets
# ipykernel==5.1.1=py36h5ca1d4c_0 -> traitlets[version='>=4.1']
# Package google-auth-oauthlib conflicts for:
# gcsfs==0.3.0=py_0 -> google-auth-oauthlib
# Package libstdcxx-ng conflicts for:
# cartopy==0.17.0=py36hd759880_1006 -> libstdcxx-ng[version='>=7.3.0']
# numcodecs==0.6.3=py36hf484d3e_0 -> libstdcxx-ng[version='>=7.3.0']
# scipy==1.3.0=py36h921218d_1 -> libstdcxx-ng[version='>=7.3.0']
# zstd==1.4.0=h3b9ef0a_0 -> libstdcxx-ng[version='>=7.3.0']
# blosc==1.17.0=he1b5a44_0 -> libstdcxx-ng[version='>=7.3.0']
# scikit-allel==1.2.1=py36hb3f55d8_0 -> libstdcxx-ng[version='>=7.3.0']
# hdf5==1.10.4=nompi_h3c11f04_1106 -> libstdcxx-ng[version='>=7.3.0']
# geos==3.7.2=he1b5a44_1 -> libstdcxx-ng[version='>=7.3.0']
# cython==0.29.13=py36he1b5a44_0 -> libstdcxx-ng[version='>=7.3.0']
# nodejs==11.14.0=he1b5a44_1 -> libstdcxx-ng[version='>=7.3.0']
# kiwisolver==1.1.0=py36hc9558a2_0 -> libstdcxx-ng[version='>=7.3.0']
# lz4-c==1.8.3=he1b5a44_1001 -> libstdcxx-ng[version='>=7.3.0']
# hdf4==4.2.13=h9a582f1_1002 -> libstdcxx-ng[version='>=7.3.0']
# krb5==1.16.3=h05b26f9_1001 -> libstdcxx-ng[version='>=7.3.0']
# llvmlite==0.29.0=py36hfd453ef_1 -> libstdcxx-ng[version='>=7.3.0']
# proj4==5.2.0=he1b5a44_1004 -> libstdcxx-ng[version='>=7.3.0']
# pyqt==5.9.2=py36hcca6a23_2 -> libstdcxx-ng[version='>=7.3.0']
# pomegranate==0.11.0=py36h9de70de_0 -> libstdcxx-ng[version='>=7.3.0']
# numexpr==2.6.9=py36h637b7d7_1000 -> libstdcxx-ng[version='>=7.3.0']
# glib==2.58.3=h6f030ca_1002 -> libstdcxx-ng[version='>=7.3.0']
# bcolz==1.2.1=py36h637b7d7_1001 -> libstdcxx-ng[version='>=7.3.0']
# python-snappy==0.5.4=py36hee44bf9_0 -> libstdcxx-ng[version='>=7.3.0']
# libffi==3.2.1=he1b5a44_1006 -> libstdcxx-ng[version='>=7.3.0']
# msgpack-python==0.6.1=py36h6bb024c_0 -> libstdcxx-ng[version='>=7.3.0']
# pytables==3.5.2=py36ha1aa75f_0 -> libstdcxx-ng[version='>=7.3.0']
# pyzmq==18.0.2=py36h1768529_2 -> libstdcxx-ng[version='>=7.3.0']
# ncurses==6.1=hf484d3e_1002 -> libstdcxx-ng[version='>=7.3.0']
# scikit-learn==0.21.3=py36hcdab131_0 -> libstdcxx-ng[version='>=7.3.0']
# libtiff==4.0.10=h57b8799_1003 -> libstdcxx-ng[version='>=7.3.0']
# scikit-image==0.15.0=py36hb3f55d8_2 -> libstdcxx-ng[version='>=7.3.0']
# python==3.6.7=h357f687_1005 -> libstdcxx-ng[version='>=7.3.0']
# numba==0.45.1=py36hb3f55d8_0 -> libstdcxx-ng[version='>=7.3.0']
# icu==64.2=he1b5a44_0 -> libstdcxx-ng[version='>=7.3.0']
# matplotlib-base==3.1.1=py36he7580a8_1 -> libstdcxx-ng[version='>=7.3.0']
# libprotobuf==3.9.1=h8b12597_0 -> libstdcxx-ng[version='>=7.3.0']
# graphite2==1.3.13=hf484d3e_1000 -> libstdcxx-ng[version='>=7.3.0']
# pcre==8.41=hf484d3e_1003 -> libstdcxx-ng[version='>=7.3.0']
# harfbuzz==2.4.0=h9f30f68_2 -> libstdcxx-ng[version='>=7.3.0']
# protobuf==3.9.1=py36he1b5a44_0 -> libstdcxx-ng[version='>=7.3.0']
# mysql-connector-c==6.1.11=hd2bbab6_1003 -> libstdcxx-ng[version='>=7.3.0']
# zeromq==4.3.2=he1b5a44_2 -> libstdcxx-ng[version='>=7.3.0']
# sip==4.19.8=py36hf484d3e_1000 -> libstdcxx-ng[version='>=7.3.0']
# gst-plugins-base==1.14.5=h0935bb2_0 -> libstdcxx-ng[version='>=7.3.0']
# expat==2.2.5=he1b5a44_1003 -> libstdcxx-ng[version='>=7.3.0']
# thrift==0.11.0=py36hf484d3e_1001 -> libstdcxx-ng[version='>=7.3.0']
# graphviz==2.38.0=hf68f40c_1011 -> libstdcxx-ng[version='>=7.3.0']
# snappy==1.1.7=he1b5a44_1002 -> libstdcxx-ng[version='>=7.3.0']
# qt==5.9.7=h0c104cb_3 -> libstdcxx-ng[version='>=7.3.0']
# pandas==0.25.0=py36hb3f55d8_0 -> libstdcxx-ng[version='>=7.3.0']
# fastcluster==1.1.25=py36h637b7d7_1000 -> libstdcxx-ng[version='>=7.3.0']
# Package python-dateutil conflicts for:
# python-kubernetes==10.0.0=py36_0 -> python-dateutil[version='>=2.5.3']
# alembic==1.0.11=py_0 -> python-dateutil
# owslib==0.18.0=py_0 -> python-dateutil[version='>=1.5']
# botocore==1.12.202=py_0 -> python-dateutil[version='>=2.1,<3.0.0']
# matplotlib-base==3.1.1=py36he7580a8_1 -> python-dateutil
# pandas==0.25.0=py36hb3f55d8_0 -> python-dateutil[version='>=2.6.1']
# bokeh==1.3.2=py36_0 -> python-dateutil[version='>=2.1']
# jupyter_client==5.3.1=py_0 -> python-dateutil[version='>=2.1']
# jupyterhub==1.0.0=py36_0 -> python-dateutil
# adal==1.2.2=py_0 -> python-dateutil[version='>=2.1.0']
# Package scipy conflicts for:
# cartopy==0.17.0=py36hd759880_1006 -> scipy
# seaborn==0.9.0=py_1 -> scipy[version='>=0.15.2']
# scikit-image==0.15.0=py36hb3f55d8_2 -> scipy[version='>=0.17']
# dask-ml==1.0.0=py_0 -> scipy
# scikit-allel==1.2.1=py36hb3f55d8_0 -> scipy
# hmmlearn==0.2.1=py36h3010b51_1000 -> scipy[version='>=0.16.0']
# dask-glm==0.1.0=0 -> scipy[version='>=0.18.1']
# pomegranate==0.11.0=py36h9de70de_0 -> scipy[version='>=0.17.0']
# scikit-learn==0.21.3=py36hcdab131_0 -> scipy
# matplotlib-venn==0.11.5=py_1 -> scipy
# statsmodels==0.10.1=py36hc1659b7_0 -> scipy[version='>=0.14']
# lmfit==0.9.13=pyh24bf2e0_0 -> scipy[version='>=0.17']
# patsy==0.5.1=py_0 -> scipy
# Package libgcc-ng conflicts for:
# hdf5==1.10.4=nompi_h3c11f04_1106 -> libgcc-ng[version='>=7.3.0']
# xorg-libxpm==3.5.12=h14c3975_1002 -> libgcc-ng[version='>=7.3.0']
# icu==64.2=he1b5a44_0 -> libgcc-ng[version='>=7.3.0']
# numexpr==2.6.9=py36h637b7d7_1000 -> libgcc-ng[version='>=7.3.0']
# ncurses==6.1=hf484d3e_1002 -> libgcc-ng[version='>=7.3.0']
# libpng==1.6.37=hed695b0_0 -> libgcc-ng[version='>=7.3.0']
# krb5==1.16.3=h05b26f9_1001 -> libgcc-ng[version='>=7.3.0']
# cartopy==0.17.0=py36hd759880_1006 -> libgcc-ng[version='>=7.3.0']
# libiconv==1.15=h516909a_1005 -> libgcc-ng[version='>=7.3.0']
# thrift==0.11.0=py36hf484d3e_1001 -> libgcc-ng[version='>=7.3.0']
# dbus==1.13.6=he372182_0 -> libgcc-ng[version='>=7.3.0']
# pycurl==7.43.0.2=py36h16ce93b_1 -> libgcc-ng[version='>=7.3.0']
# expat==2.2.5=he1b5a44_1003 -> libgcc-ng[version='>=7.3.0']
# libcurl==7.65.3=hda55be3_0 -> libgcc-ng[version='>=7.3.0']
# sqlalchemy==1.3.6=py36h516909a_0 -> libgcc-ng[version='>=7.3.0']
# fontconfig==2.13.1=h86ecdb6_1001 -> libgcc-ng[version='>=7.3.0']
# xorg-xproto==7.0.31=h14c3975_1007 -> libgcc-ng[version='>=7.3.0']
# python-snappy==0.5.4=py36hee44bf9_0 -> libgcc-ng[version='>=7.3.0']
# scikit-image==0.15.0=py36hb3f55d8_2 -> libgcc-ng[version='>=7.3.0']
# xorg-libx11==1.6.8=h516909a_0 -> libgcc-ng[version='>=7.3.0']
# h5py==2.9.0=nompi_py36hcafd542_1103 -> libgcc-ng[version='>=7.3.0']
# cryptography==2.7=py36h72c5cf5_0 -> libgcc-ng[version='>=7.3.0']
# cytoolz==0.10.0=py36h516909a_0 -> libgcc-ng[version='>=7.3.0']
# pysamstats==1.1.2=py36h84994c4_3 -> libgcc-ng[version='>=7.3.0']
# wrapt==1.11.2=py36h516909a_0 -> libgcc-ng[version='>=7.3.0']
# graphite2==1.3.13=hf484d3e_1000 -> libgcc-ng[version='>=7.3.0']
# nodejs==11.14.0=he1b5a44_1 -> libgcc-ng[version='>=7.3.0']
# biopython==1.74=py36h516909a_0 -> libgcc-ng[version='>=7.3.0']
# sqlite==3.29.0=hcee41ef_0 -> libgcc-ng[version='>=7.3.0']
# libxcb==1.13=h14c3975_1002 -> libgcc-ng[version='>=7.3.0']
# hdf4==4.2.13=h9a582f1_1002 -> libgcc-ng[version='>=7.3.0']
# pandas==0.25.0=py36hb3f55d8_0 -> libgcc-ng[version='>=7.3.0']
# pysam==0.15.3=py36h5ad169c_0 -> libgcc-ng[version='>=7.3.0']
# gsl==2.5=h294904e_0 -> libgcc-ng[version='>=7.3.0']
# glib==2.58.3=h6f030ca_1002 -> libgcc-ng[version='>=7.3.0']
# xorg-libxext==1.3.4=h516909a_0 -> libgcc-ng[version='>=7.3.0']
# qt==5.9.7=h0c104cb_3 -> libgcc-ng[version='>=7.3.0']
# aiohttp==3.5.4=py36h14c3975_0 -> libgcc-ng[version='>=7.3.0']
# multidict==4.5.2=py36h14c3975_1000 -> libgcc-ng[version='>=7.3.0']
# blosc==1.17.0=he1b5a44_0 -> libgcc-ng[version='>=7.3.0']
# xorg-libxau==1.0.9=h14c3975_0 -> libgcc-ng[version='>=7.3.0']
# pyrsistent==0.15.4=py36h516909a_0 -> libgcc-ng[version='>=7.3.0']
# freetype==2.10.0=he983fc9_0 -> libgcc-ng[version='>=7.3.0']
# numpy==1.17.0=py36h95a1406_0 -> libgcc-ng[version='>=7.3.0']
# libtool==2.4.6=h14c3975_1002 -> libgcc-ng[version='>=7.3.0']
# blas==2.11=openblas -> libgcc-ng[version='>=7.3.0']
# gettext==0.19.8.1=hc5be6a0_1002 -> libgcc-ng[version='>=7.3.0']
# openssl -> libgcc-ng[version='>=4.9|>=7.2.0|>=7.3.0']
# pygraphviz==1.5=py36h516909a_1001 -> libgcc-ng[version='>=7.3.0']
# tskit==0.1.5=py36hd352d35_0 -> libgcc-ng[version='>=7.3.0']
# msprime==0.7.3=py36heade8f8_0 -> libgcc-ng[version='>=7.3.0']
# pyproj==1.9.6=py36h516909a_1002 -> libgcc-ng[version='>=7.3.0']
# libtiff==4.0.10=h57b8799_1003 -> libgcc-ng[version='>=7.3.0']
# libffi==3.2.1=he1b5a44_1006 -> libgcc-ng[version='>=7.3.0']
# tornado==6.0.3=py36h516909a_0 -> libgcc-ng[version='>=7.3.0']
# pixman==0.38.0=h516909a_1003 -> libgcc-ng[version='>=7.3.0']
# pykdtree==1.3.1=py36h3010b51_1002 -> libgcc-ng[version='>=7.3.0']
# fastcluster==1.1.25=py36h637b7d7_1000 -> libgcc-ng[version='>=7.3.0']
# scipy==1.3.0=py36h921218d_1 -> libgcc-ng[version='>=7.3.0']
# ruamel.yaml==0.16.0=py36h516909a_0 -> libgcc-ng[version='>=7.3.0']
# yaml==0.1.7=h14c3975_1001 -> libgcc-ng[version='>=7.3.0']
# matplotlib-base==3.1.1=py36he7580a8_1 -> libgcc-ng[version='>=7.3.0']
# zlib==1.2.11=h516909a_1005 -> libgcc-ng[version='>=7.3.0']
# sip==4.19.8=py36hf484d3e_1000 -> libgcc-ng[version='>=7.3.0']
# xorg-libsm==1.2.3=h84519dc_1000 -> libgcc-ng[version='>=7.3.0']
# bcolz==1.2.1=py36h637b7d7_1001 -> libgcc-ng[version='>=7.3.0']
# xorg-libice==1.0.10=h516909a_0 -> libgcc-ng[version='>=7.3.0']
# snappy==1.1.7=he1b5a44_1002 -> libgcc-ng[version='>=7.3.0']
# numcodecs==0.6.3=py36hf484d3e_0 -> libgcc-ng[version='>=7.3.0']
# netcdf4==1.5.1.2=py36had58050_0 -> libgcc-ng[version='>=7.3.0']
# pango==1.40.14=he7ab937_1005 -> libgcc-ng[version='>=7.3.0']
# bcrypt==3.1.6=py36h516909a_1 -> libgcc-ng[version='>=7.3.0']
# pyyaml==5.1.2=py36h516909a_0 -> libgcc-ng[version='>=7.3.0']
# llvmlite==0.29.0=py36hfd453ef_1 -> libgcc-ng[version='>=7.3.0']
# mysql-connector-c==6.1.11=hd2bbab6_1003 -> libgcc-ng[version='>=7.3.0']
# xorg-renderproto==0.11.1=h14c3975_1002 -> libgcc-ng[version='>=7.3.0']
# xorg-libxrender==0.9.10=h516909a_1002 -> libgcc-ng[version='>=7.3.0']
# xorg-libxdmcp==1.1.3=h516909a_0 -> libgcc-ng[version='>=7.3.0']
# protobuf==3.9.1=py36he1b5a44_0 -> libgcc-ng[version='>=7.3.0']
# pywavelets==1.0.3=py36hd352d35_1 -> libgcc-ng[version='>=7.3.0']
# scikit-learn==0.21.3=py36hcdab131_0 -> libgcc-ng[version='>=7.3.0']
# cftime==1.0.3.4=py36hd352d35_1001 -> libgcc-ng[version='>=7.3.0']
# readline==8.0=hf8c457e_0 -> libgcc-ng[version='>=7.3.0']
# tk==8.6.9=hed695b0_1002 -> libgcc-ng[version='>=7.3.0']
# pomegranate==0.11.0=py36h9de70de_0 -> libgcc-ng[version='>=7.3.0']
# libssh2==1.8.2=h22169c7_2 -> libgcc-ng[version='>=7.3.0']
# cairo==1.16.0=hfb77d84_1002 -> libgcc-ng[version='>=7.3.0']
# graphviz==2.38.0=hf68f40c_1011 -> libgcc-ng[version='>=7.3.0']
# scikit-allel==1.2.1=py36hb3f55d8_0 -> libgcc-ng[version='>=7.3.0']
# libopenblas==0.3.6=h6e990d7_6 -> libgcc-ng[version='>=7.3.0']
# libedit==3.1.20170329=hf8c457e_1001 -> libgcc-ng[version='>=7.3.0']
# msgpack-python==0.6.1=py36h6bb024c_0 -> libgcc-ng[version='>=7.3.0']
# pcre==8.41=hf484d3e_1003 -> libgcc-ng[version='>=7.3.0']
# jpeg==9c=h14c3975_1001 -> libgcc-ng[version='>=7.3.0']
# bcftools==1.9=ha228f0b_4 -> libgcc-ng[version='>=7.3.0']
# python==3.6.7=h357f687_1005 -> libgcc-ng[version='>=7.3.0']
# yarl==1.3.0=py36h14c3975_1000 -> libgcc-ng[version='>=7.3.0']
# xorg-libxt==1.1.5=h516909a_1003 -> libgcc-ng[version='>=7.3.0']
# lz4-c==1.8.3=he1b5a44_1001 -> libgcc-ng[version='>=7.3.0']
# pillow==6.1.0=py36h6b7be26_1 -> libgcc-ng[version='>=7.3.0']
# markupsafe==1.1.1=py36h14c3975_0 -> libgcc-ng[version='>=7.3.0']
# harfbuzz==2.4.0=h9f30f68_2 -> libgcc-ng[version='>=7.3.0']
# statsmodels==0.10.1=py36hc1659b7_0 -> libgcc-ng[version='>=7.3.0']
# shapely==1.6.4=py36hec07ddf_1006 -> libgcc-ng[version='>=7.3.0']
# xorg-xextproto==7.3.0=h14c3975_1002 -> libgcc-ng[version='>=7.3.0']
# gstreamer==1.14.5=h36ae1b5_0 -> libgcc-ng[version='>=7.3.0']
# cffi==1.12.3=py36h8022711_0 -> libgcc-ng[version='>=7.3.0']
# xorg-kbproto==1.0.7=h14c3975_1002 -> libgcc-ng[version='>=7.3.0']
# curl==7.65.3=hf8cf82a_0 -> libgcc-ng[version='>=7.3.0']
# pyzmq==18.0.2=py36h1768529_2 -> libgcc-ng[version='>=7.3.0']
# libxml2==2.9.9=hee79883_2 -> libgcc-ng[version='>=7.3.0']
# bzip2==1.0.8=h516909a_0 -> libgcc-ng[version='>=7.3.0']
# pynacl==1.3.0=py36h14c3975_1000 -> libgcc-ng[version='>=7.3.0']
# hmmlearn==0.2.1=py36h3010b51_1000 -> libgcc-ng[version='>=7.3.0']
# libsodium==1.0.17=h516909a_0 -> libgcc-ng[version='>=7.3.0']
# geos==3.7.2=he1b5a44_1 -> libgcc-ng[version='>=7.3.0']
# zeromq==4.3.2=he1b5a44_2 -> libgcc-ng[version='>=7.3.0']
# cython==0.29.13=py36he1b5a44_0 -> libgcc-ng[version='>=7.3.0']
# libprotobuf==3.9.1=h8b12597_0 -> libgcc-ng[version='>=7.3.0']
# gst-plugins-base==1.14.5=h0935bb2_0 -> libgcc-ng[version='>=7.3.0']
# libnetcdf==4.6.2=hbdf4f91_1001 -> libgcc-ng[version='>=7.3.0']
# proj4==5.2.0=he1b5a44_1004 -> libgcc-ng[version='>=7.3.0']
# zstd==1.4.0=h3b9ef0a_0 -> libgcc-ng[version='>=7.3.0']
# lzo==2.10=h14c3975_1000 -> libgcc-ng[version='>=7.3.0']
# psutil==5.6.3=py36h516909a_0 -> libgcc-ng[version='>=7.3.0']
# pthread-stubs==0.4=h14c3975_1001 -> libgcc-ng[version='>=7.3.0']
# pyqt==5.9.2=py36hcca6a23_2 -> libgcc-ng[version='>=7.3.0']
# kiwisolver==1.1.0=py36hc9558a2_0 -> libgcc-ng[version='>=7.3.0']
# samtools==1.9=h8571acd_11 -> libgcc-ng[version='>=7.3.0']
# pytables==3.5.2=py36ha1aa75f_0 -> libgcc-ng[version='>=7.3.0']
# xz==5.2.4=h14c3975_1001 -> libgcc-ng[version='>=7.3.0']
# htslib==1.9=ha228f0b_7 -> libgcc-ng[version='>=7.3.0']
# fastparquet==0.3.2=py36hc1659b7_0 -> libgcc-ng[version='>=7.3.0']
# datrie==0.8=py36h516909a_0 -> libgcc-ng[version='>=7.3.0']
# numba==0.45.1=py36hb3f55d8_0 -> libgcc-ng[version='>=7.3.0']
# mistune==0.8.4=py36h14c3975_1000 -> libgcc-ng[version='>=7.3.0']
# libuuid==2.32.1=h14c3975_1000 -> libgcc-ng[version='>=7.3.0']
# Package pywavelets conflicts for:
# scikit-image==0.15.0=py36hb3f55d8_2 -> pywavelets[version='>=0.4.0']
# Package zarr conflicts for:
# scikit-allel==1.2.1=py36hb3f55d8_0 -> zarr[version='>=2.2']
# intake-xarray==0.3.1=py_0 -> zarr
# Package google-auth conflicts for:
# google-auth-oauthlib==0.4.0=py_0 -> google-auth
# google-api-core==1.14.2=py36_0 -> google-auth[version='>=0.4.0,<2.0.0dev']
# gcsfs==0.3.0=py_0 -> google-auth
# google-cloud-storage==1.17.0=py_0 -> google-auth[version='>=1.2.0']
# python-kubernetes==10.0.0=py36_0 -> google-auth[version='>=1.0.1']
# Package libblas conflicts for:
# liblapack==3.8.0=11_openblas -> libblas==3.8.0=11_openblas
# libcblas==3.8.0=11_openblas -> libblas==3.8.0=11_openblas
# scipy==1.3.0=py36h921218d_1 -> libblas[version='>=3.8.0,<4.0a0']
# blas==2.11=openblas -> libblas==3.8.0=11_openblas
# liblapacke==3.8.0=11_openblas -> libblas==3.8.0=11_openblas
# gsl==2.5=h294904e_0 -> libblas[version='>=3.8.0,<4.0a0']
# numpy==1.17.0=py36h95a1406_0 -> libblas[version='>=3.8.0,<4.0a0']
# Package matplotlib conflicts for:
# scikit-allel==1.2.1=py36hb3f55d8_0 -> matplotlib
# matplotlib-venn==0.11.5=py_1 -> matplotlib
# cartopy==0.17.0=py36hd759880_1006 -> matplotlib
# Package xorg-libsm conflicts for:
# cairo==1.16.0=hfb77d84_1002 -> xorg-libsm
# xorg-libxt==1.1.5=h516909a_1003 -> xorg-libsm=1.2
# Package libsodium conflicts for:
# pyzmq==18.0.2=py36h1768529_2 -> libsodium[version='>=1.0.17,<1.0.18.0a0']
# zeromq==4.3.2=he1b5a44_2 -> libsodium[version='>=1.0.17,<1.0.18.0a0']
# Package dask-core conflicts for:
# dask==2.2.0=py_0 -> dask-core=2.2.0
# distributed==2.2.0=py_1 -> dask-core[version='>=2']
# scikit-image==0.15.0=py36hb3f55d8_2 -> dask-core[version='>=0.9.0']
# dask-kubernetes==0.9.1=py_0 -> dask-core[version='>=0.19.0']
# Package matplotlib-base conflicts for:
# scikit-image==0.15.0=py36hb3f55d8_2 -> matplotlib-base[version='>=2.0.0']
# holoviews==1.12.4=py_0 -> matplotlib-base[version='>=2.1']
# matplotlib==3.1.1=py36_1 -> matplotlib-base==3.1.1=py36he7580a8_1
# seaborn==0.9.0=py_1 -> matplotlib-base
# Package ipython conflicts for:
# jupyter_console==6.0.0=py_0 -> ipython
# holoviews==1.12.4=py_0 -> ipython[version='>=5.4.0']
# ipykernel==5.1.1=py36h5ca1d4c_0 -> ipython[version='>=5.0']
# ipywidgets==7.5.1=py_0 -> ipython[version='>=4.0.0']
# Package jsonschema conflicts for:
# nbformat==4.4.0=py_1 -> jsonschema[version='>=2.4,!=2.5.0']
# tskit==0.1.5=py36hd352d35_0 -> jsonschema
# msprime==0.7.3=py36heade8f8_0 -> jsonschema
# snakemake==5.5.4=1 -> jsonschema
# jupyterlab_server==1.0.0=py_1 -> jsonschema[version='>=3.0.1']
# snakemake-minimal==5.5.4=py_1 -> jsonschema
# Package curl conflicts for:
# htslib==1.9=ha228f0b_7 -> curl[version='>=7.64.0,<8.0a0']
# samtools==1.9=h8571acd_11 -> curl[version='>=7.64.0,<8.0a0']
# libnetcdf==4.6.2=hbdf4f91_1001 -> curl[version='>=7.59.0,<8.0a0']
# pysam==0.15.3=py36h5ad169c_0 -> curl[version='>=7.64.1,<8.0a0']
# bcftools==1.9=ha228f0b_4 -> curl[version='>=7.64.1,<8.0a0']
# Package google-cloud-storage conflicts for:
# snakemake==5.5.4=1 -> google-cloud-storage
# Package libopenblas conflicts for:
# libblas==3.8.0=11_openblas -> libopenblas[version='>=0.3.6,<0.3.7.0a0,>=0.3.6,<1.0a0']
# Package psutil conflicts for:
# distributed==2.2.0=py_1 -> psutil[version='>=5.0']
# snakemake-minimal==5.5.4=py_1 -> psutil
# snakemake==5.5.4=1 -> psutil
# Package sortedcontainers conflicts for:
# distributed==2.2.0=py_1 -> sortedcontainers[version='!=2.0.0,!=2.0.1']
# intervaltree==3.0.2=py_0 -> sortedcontainers
# Package six conflicts for:
# cycler==0.10.0=py_1 -> six
# google-resumable-media==0.3.2=py_0 -> six
# lmfit==0.9.13=pyh24bf2e0_0 -> six
# thrift==0.11.0=py36hf484d3e_1001 -> six[version='>=1.7.2']
# python-kubernetes==10.0.0=py36_0 -> six[version='>=1.9.0']
# patsy==0.5.1=py_0 -> six
# pytables==3.5.2=py36ha1aa75f_0 -> six
# cartopy==0.17.0=py36hd759880_1006 -> six
# dask-ml==1.0.0=py_0 -> six
# python-irodsclient==0.7.0=py_0 -> six[version='>=1.10.0']
# google-auth==1.6.3=py_0 -> six[version='>=1.9.0,<2dev']
# pyopenssl==19.0.0=py36_0 -> six[version='>=1.5.2']
# h5py==2.9.0=nompi_py36hcafd542_1103 -> six
# protobuf==3.9.1=py36he1b5a44_0 -> six
# cryptography==2.7=py36h72c5cf5_0 -> six[version='>=1.4.1']
# asteval==0.9.14=pyh24bf2e0_0 -> six
# bokeh==1.3.2=py36_0 -> six[version='>=1.5.2']
# pynacl==1.3.0=py36h14c3975_1000 -> six
# jsonschema==3.0.2=py36_0 -> six[version='>=1.11.0']
# pyfaidx==0.5.5.2=py_1 -> six
# aioeasywebdav==2.4.0=py36_1000 -> six
# tskit==0.1.5=py36hd352d35_0 -> six
# traitlets==4.3.2=py36_1000 -> six
# mock==3.0.5=py36_0 -> six
# branca==0.3.1=py_0 -> six
# multipledispatch==0.6.0=py_0 -> six
# bcrypt==3.1.6=py36h516909a_1 -> six[version='>=1.4.1']
# google-api-core==1.14.2=py36_0 -> six[version='>=1.10.0']
# fasteners==0.14.1=py_3 -> six
# bleach==3.1.0=py_0 -> six
# websocket-client==0.56.0=py36_0 -> six
# distributed==2.2.0=py_1 -> six
# python-dateutil==2.8.0=py_0 -> six
# prompt_toolkit==2.0.9=py_0 -> six[version='>=1.9.0']
# packaging==19.0=py_0 -> six
# msprime==0.7.3=py36heade8f8_0 -> six
# dropbox==9.4.0=py_0 -> six[version='>=1.3.0']
# pyrsistent==0.15.4=py36h516909a_0 -> six
# Package gsl conflicts for:
# msprime==0.7.3=py36heade8f8_0 -> gsl[version='>=2.5,<2.6.0a0']
# Package oauthlib conflicts for:
# requests-oauthlib==1.2.0=py_0 -> oauthlib[version='>=0.6.2']
# jupyterhub==1.0.0=py36_0 -> oauthlib[version='>=3.0']
# Package xz conflicts for:
# bcftools==1.9=ha228f0b_4 -> xz[version='>=5.2.4,<5.3.0a0']
# htslib==1.9=ha228f0b_7 -> xz[version='>=5.2.4,<5.3.0a0']
# zstd==1.4.0=h3b9ef0a_0 -> xz[version='>=5.2.4,<5.3.0a0']
# gst-plugins-base==1.14.5=h0935bb2_0 -> xz[version='>=5.2.4,<5.3.0a0']
# libtiff==4.0.10=h57b8799_1003 -> xz[version='>=5.2.4,<5.3.0a0']
# libxml2==2.9.9=hee79883_2 -> xz[version='>=5.2.4,<5.3.0a0']
# python==3.6.7=h357f687_1005 -> xz[version='>=5.2.4,<5.3.0a0']
# samtools==1.9=h8571acd_11 -> xz[version='>=5.2.4,<5.3.0a0']
# gstreamer==1.14.5=h36ae1b5_0 -> xz[version='>=5.2.4,<5.3.0a0']
# Package pyasn1-modules conflicts for:
# google-auth==1.6.3=py_0 -> pyasn1-modules[version='>=0.2.1']
# Package numexpr conflicts for:
# pytables==3.5.2=py36ha1aa75f_0 -> numexpr
# scikit-allel==1.2.1=py36hb3f55d8_0 -> numexpr
# bcolz==1.2.1=py36h637b7d7_1001 -> numexpr
# Package requests conflicts for:
# requests-oauthlib==1.2.0=py_0 -> requests[version='>=2.0.0']
# intake==0.5.2=py_0 -> requests
# pyepsg==0.4.0=py_0 -> requests
# snakemake-minimal==5.5.4=py_1 -> requests[version='>=2.8.1']
# python-kubernetes==10.0.0=py36_0 -> requests
# owslib==0.18.0=py_0 -> requests[version='>=1.0']
# adal==1.2.2=py_0 -> requests[version='>=2.0.0']
# gcsfs==0.3.0=py_0 -> requests
# google-api-core==1.14.2=py36_0 -> requests[version='>=2.18.0,<3.0.0dev']
# jupyterhub==1.0.0=py36_0 -> requests
# dropbox==9.4.0=py_0 -> requests[version='>=2.16.2']
# Package markupsafe conflicts for:
# mako==1.1.0=py_0 -> markupsafe[version='>=0.9.2']
# jinja2==2.10.1=py_0 -> markupsafe[version='>=0.23']
# Package pillow conflicts for:
# bokeh==1.3.2=py36_0 -> pillow[version='>=4.0']
# cartopy==0.17.0=py36hd759880_1006 -> pillow
# scikit-image==0.15.0=py36hb3f55d8_2 -> pillow[version='>=4.3.0']
# imageio==2.5.0=py36_0 -> pillow
# Package tk conflicts for:
# matplotlib-base==3.1.1=py36he7580a8_1 -> tk[version='>=8.6.9,<8.7.0a0']
# python==3.6.7=h357f687_1005 -> tk[version='>=8.6.9,<8.7.0a0']
# pillow==6.1.0=py36h6b7be26_1 -> tk[version='>=8.6.9,<8.7.0a0']
# krb5==1.16.3=h05b26f9_1001 -> tk[version='>=8.6.9,<8.7.0a0']
# Package tblib conflicts for:
# distributed==2.2.0=py_1 -> tblib
# Package asteval conflicts for:
# lmfit==0.9.13=pyh24bf2e0_0 -> asteval[version='>=0.9.11']
# Package setuptools conflicts for:
# numexpr==2.6.9=py36h637b7d7_1000 -> setuptools
# bleach==3.1.0=py_0 -> setuptools
# python-kubernetes==10.0.0=py36_0 -> setuptools[version='>=21.0.0']
# dask-ml==1.0.0=py_0 -> setuptools
# google-api-core==1.14.2=py36_0 -> setuptools[version='>=34.0.0']
# jinja2==2.10.1=py_0 -> setuptools
# dask-glm==0.1.0=0 -> setuptools
# netcdf4==1.5.1.2=py36had58050_0 -> setuptools
# jsonschema==3.0.2=py36_0 -> setuptools
# dropbox==9.4.0=py_0 -> setuptools
# pip==19.2.1=py36_0 -> setuptools
# nose==1.3.7=py36_1002 -> setuptools
# ruamel.yaml==0.16.0=py36h516909a_0 -> setuptools
# pygments==2.4.2=py_0 -> setuptools
# networkx==2.3=py_0 -> setuptools
# hmmlearn==0.2.1=py36h3010b51_1000 -> setuptools
# protobuf==3.9.1=py36he1b5a44_0 -> setuptools
# wheel==0.33.4=py36_0 -> setuptools
# snakemake-minimal==5.5.4=py_1 -> setuptools
# asteval==0.9.14=pyh24bf2e0_0 -> setuptools
# matplotlib-base==3.1.1=py36he7580a8_1 -> setuptools
# branca==0.3.1=py_0 -> setuptools
# Package prettytable conflicts for:
# python-irodsclient==0.7.0=py_0 -> prettytable[version='>=0.7.2']
# Package fsspec conflicts for:
# gcsfs==0.3.0=py_0 -> fsspec
# s3fs==0.3.1=py_0 -> fsspec
# dask==2.2.0=py_0 -> fsspec[version='>=0.4.0']
# Package bzip2 conflicts for:
# bcftools==1.9=ha228f0b_4 -> bzip2[version='>=1.0.6,<2.0a0']
# samtools==1.9=h8571acd_11 -> bzip2[version='>=1.0.6,<2.0a0']
# libnetcdf==4.6.2=hbdf4f91_1001 -> bzip2[version='>=1.0.6,<2.0a0']
# pytables==3.5.2=py36ha1aa75f_0 -> bzip2[version='>=1.0.6,<2.0a0']
# htslib==1.9=ha228f0b_7 -> bzip2[version='>=1.0.6,<2.0a0']
# Package zlib conflicts for:
# curl==7.65.3=hf8cf82a_0 -> zlib[version='>=1.2.11,<1.3.0a0']
# gst-plugins-base==1.14.5=h0935bb2_0 -> zlib[version='>=1.2.11,<1.3.0a0']
# llvmlite==0.29.0=py36hfd453ef_1 -> zlib[version='>=1.2.11,<1.3.0a0']
# bcftools==1.9=ha228f0b_4 -> zlib[version='>=1.2.11,<1.3.0a0']
# libtiff==4.0.10=h57b8799_1003 -> zlib[version='>=1.2.11,<1.3.0a0']
# pillow==6.1.0=py36h6b7be26_1 -> zlib[version='>=1.2.11,<1.3.0a0']
# cairo==1.16.0=hfb77d84_1002 -> zlib[version='>=1.2.11,<1.3.0a0']
# freetype==2.10.0=he983fc9_0 -> zlib[version='>=1.2.11,<1.3.0a0']
# libxml2==2.9.9=hee79883_2 -> zlib[version='>=1.2.11,<1.3.0a0']
# hdf4==4.2.13=h9a582f1_1002 -> zlib[version='>=1.2.11,<1.3.0a0']
# python==3.6.7=h357f687_1005 -> zlib[version='>=1.2.11,<1.3.0a0']
# hdf5==1.10.4=nompi_h3c11f04_1106 -> zlib[version='>=1.2.11,<1.3.0a0']
# libprotobuf==3.9.1=h8b12597_0 -> zlib[version='>=1.2.11,<1.3.0a0']
# libssh2==1.8.2=h22169c7_2 -> zlib[version='>=1.2.11,<1.3.0a0']
# libnetcdf==4.6.2=hbdf4f91_1001 -> zlib[version='>=1.2.11,<1.3.0a0']
# pysamstats==1.1.2=py36h84994c4_3 -> zlib[version='>=1.2.11,<1.3.0a0']
# libcurl==7.65.3=hda55be3_0 -> zlib[version='>=1.2.11,<1.3.0a0']
# graphviz==2.38.0=hf68f40c_1011 -> zlib[version='>=1.2.11,<1.3.0a0']
# htslib==1.9=ha228f0b_7 -> zlib[version='>=1.2.11,<1.3.0a0']
# samtools==1.9=h8571acd_11 -> zlib[version='>=1.2.11,<1.3.0a0']
# pysam==0.15.3=py36h5ad169c_0 -> zlib[version='>=1.2.11,<1.3.0a0']
# pytables==3.5.2=py36ha1aa75f_0 -> zlib[version='>=1.2.11,<1.3.0a0']
# libpng==1.6.37=hed695b0_0 -> zlib[version='>=1.2.11,<1.3.0a0']
# qt==5.9.7=h0c104cb_3 -> zlib[version='>=1.2.11,<1.3.0a0']
# tk==8.6.9=hed695b0_1002 -> zlib[version='>=1.2.11,<1.3.0a0']
# glib==2.58.3=h6f030ca_1002 -> zlib[version='>=1.2.11,<1.3.0a0']
# zstd==1.4.0=h3b9ef0a_0 -> zlib[version='>=1.2.11,<1.3.0a0']
# Package snakemake-minimal conflicts for:
# snakemake==5.5.4=1 -> snakemake-minimal=5.5.4
# Package libiconv conflicts for:
# glib==2.58.3=h6f030ca_1002 -> libiconv[version='>=1.15,<1.16.0a0']
# libxml2==2.9.9=hee79883_2 -> libiconv[version='>=1.15,<1.16.0a0']
# Package decorator conflicts for:
# networkx==2.3=py_0 -> decorator[version='>=4.3.0']
# ipython==7.7.0=py36h5ca1d4c_0 -> decorator
# gcsfs==0.3.0=py_0 -> decorator
# traitlets==4.3.2=py36_1000 -> decorator
# Package liblapack conflicts for:
# blas==2.11=openblas -> liblapack==3.8.0=11_openblas
# libcblas==3.8.0=11_openblas -> liblapack==3.8.0=11_openblas
# libblas==3.8.0=11_openblas -> liblapack==3.8.0=11_openblas
# scipy==1.3.0=py36h921218d_1 -> liblapack[version='>=3.8.0,<3.9.0a0']
# numpy==1.17.0=py36h95a1406_0 -> liblapack[version='>=3.8.0,<3.9.0a0']
# liblapacke==3.8.0=11_openblas -> liblapack==3.8.0=11_openblas
# Package pytz conflicts for:
# owslib==0.18.0=py_0 -> pytz
# pandas==0.25.0=py36hb3f55d8_0 -> pytz[version='>=2017.2']
# google-api-core==1.14.2=py36_0 -> pytz
# Package sqlalchemy conflicts for:
# alembic==1.0.11=py_0 -> sqlalchemy[version='>=0.9.0']
# jupyterhub==1.0.0=py36_0 -> sqlalchemy[version='>=1.1']
# Package jedi conflicts for:
# ipython==7.7.0=py36h5ca1d4c_0 -> jedi[version='>=0.10']
# Package notebook conflicts for:
# nbserverproxy==0.8.8=py_1000 -> notebook
# jupyterlab_server==1.0.0=py_1 -> notebook[version='>=4.2.0']
# jupyter==1.0.0=py_2 -> notebook
# widgetsnbextension==3.5.1=py36_0 -> notebook[version='>=4.4.1']
# nb_conda_kernels==2.2.2=py36_0 -> notebook[version='>=4.2.0']
# jupyterlab==1.0.4=py36_0 -> notebook[version='>=4.3.1']
# holoviews==1.12.4=py_0 -> notebook
# jupyterlab_launcher==0.13.1=py_2 -> notebook
# Package xorg-libx11 conflicts for:
# xorg-libxext==1.3.4=h516909a_0 -> xorg-libx11=1.6
# cairo==1.16.0=hfb77d84_1002 -> xorg-libx11
# xorg-libxt==1.1.5=h516909a_1003 -> xorg-libx11=1.6
# xorg-libxrender==0.9.10=h516909a_1002 -> xorg-libx11=1.6
# xorg-libxpm==3.5.12=h14c3975_1002 -> xorg-libx11=1.6
# Package pandoc conflicts for:
# nbconvert==5.5.0=py_0 -> pandoc[version='>=1.12.1']
# Package dask conflicts for:
# scikit-allel==1.2.1=py36hb3f55d8_0 -> dask[version='>=0.15']
# bcolz==1.2.1=py36h637b7d7_1001 -> dask
# intake==0.5.2=py_0 -> dask[version='>=2.2']
# dask-glm==0.1.0=0 -> dask
# intake-xarray==0.3.1=py_0 -> dask[version='>=2.2']
# dask-ml==1.0.0=py_0 -> dask[version='>=1.0.0']
# Package bokeh conflicts for:
# holoviews==1.12.4=py_0 -> bokeh[version='>=1.1.0']
# dask==2.2.0=py_0 -> bokeh[version='>=1.0.0']
# Package pygments conflicts for:
# prompt_toolkit==2.0.9=py_0 -> pygments
# ipython==7.7.0=py36h5ca1d4c_0 -> pygments
# jupyter_console==6.0.0=py_0 -> pygments
# qtconsole==4.5.2=py_0 -> pygments
# snakemake==5.5.4=1 -> pygments
# nbconvert==5.5.0=py_0 -> pygments
# Package boto3 conflicts for:
# s3fs==0.3.1=py_0 -> boto3
# snakemake==5.5.4=1 -> boto3
# Package jupyter_console conflicts for:
# jupyter==1.0.0=py_2 -> jupyter_console
# Package cffi conflicts for:
# cryptography==2.7=py36h72c5cf5_0 -> cffi[version='>=1.7']
# pynacl==1.3.0=py36h14c3975_1000 -> cffi
# bcrypt==3.1.6=py36h516909a_1 -> cffi[version='>=1.1']
# Package traittypes conflicts for:
# ipyleaflet==0.11.1=py36_1 -> traittypes[version='>=0.2.1,<0.3.0']
# bqplot==0.11.6=py_0 -> traittypes[version='>=0.0.6']
# Package libprotobuf conflicts for:
# protobuf==3.9.1=py36he1b5a44_0 -> libprotobuf[version='3.9.1.*,>=3.9.1,<3.10.0a0']
# Package liblapacke conflicts for:
# libblas==3.8.0=11_openblas -> liblapacke==3.8.0=11_openblas
# blas==2.11=openblas -> liblapacke==3.8.0=11_openblas
# libcblas==3.8.0=11_openblas -> liblapacke==3.8.0=11_openblas
# liblapack==3.8.0=11_openblas -> liblapacke==3.8.0=11_openblas
# Package libffi conflicts for:
# cffi==1.12.3=py36h8022711_0 -> libffi[version='>=3.2.1,<3.3.0a0']
# gstreamer==1.14.5=h36ae1b5_0 -> libffi[version='>=3.2.1,<3.3.0a0']
# python==3.6.7=h357f687_1005 -> libffi[version='>=3.2.1,<3.3.0a0']
# gettext==0.19.8.1=hc5be6a0_1002 -> libffi[version='>=3.2.1,<3.3.0a0']
# glib==2.58.3=h6f030ca_1002 -> libffi[version='>=3.2.1,<3.3.0a0']
# Package msgpack-numpy conflicts for:
# intake==0.5.2=py_0 -> msgpack-numpy
# Package yarl conflicts for:
# aiohttp==3.5.4=py36h14c3975_0 -> yarl[version='>=1.0,<2.0']
# Package libuuid conflicts for:
# fontconfig==2.13.1=h86ecdb6_1001 -> libuuid[version='>=2.32.1,<3.0a0']
# xorg-libsm==1.2.3=h84519dc_1000 -> libuuid[version='>=2.32.1,<3.0a0']
# Package h5py conflicts for:
# tskit==0.1.5=py36hd352d35_0 -> h5py
# msprime==0.7.3=py36heade8f8_0 -> h5py
# scikit-allel==1.2.1=py36hb3f55d8_0 -> h5py
# Package snappy conflicts for:
# python-snappy==0.5.4=py36hee44bf9_0 -> snappy[version='>=1.1.7,<1.1.8.0a0']
# Package libgfortran-ng conflicts for:
# libopenblas==0.3.6=h6e990d7_6 -> libgfortran-ng[version='>=7,<8.0a0']
# blas==2.11=openblas -> libgfortran-ng[version='>=7,<8.0a0']
# hdf5==1.10.4=nompi_h3c11f04_1106 -> libgfortran-ng[version='>=7,<8.0a0']
# scipy==1.3.0=py36h921218d_1 -> libgfortran-ng[version='>=7,<8.0a0']
# Package xorg-xextproto conflicts for:
# xorg-libxext==1.3.4=h516909a_0 -> xorg-xextproto
# xorg-libxpm==3.5.12=h14c3975_1002 -> xorg-xextproto
# Package pysocks conflicts for:
# urllib3==1.25.3=py36_0 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
# Package tornado conflicts for:
# jupyterlab==1.0.4=py36_0 -> tornado[version='!=6.0.0,!=6.0.1,!=6.0.2']
# jupyter_client==5.3.1=py_0 -> tornado[version='>=4.1']
# terminado==0.8.2=py36_0 -> tornado[version='>=4']
# matplotlib-base==3.1.1=py36he7580a8_1 -> tornado
# intake==0.5.2=py_0 -> tornado[version='>=4.5.1']
# bokeh==1.3.2=py36_0 -> tornado[version='>=4.3']
# ipykernel==5.1.1=py36h5ca1d4c_0 -> tornado[version='>=4.0']
# distributed==2.2.0=py_1 -> tornado[version='>=5']
# notebook==6.0.0=py36_0 -> tornado[version='>=5.0,<7']
# jupyterhub==1.0.0=py36_0 -> tornado[version='>=5.0']
# Package jupyterlab_server conflicts for:
# jupyterlab==1.0.4=py36_0 -> jupyterlab_server[version='>=1.0.0,<2.0.0']
# Package numba conflicts for:
# fastparquet==0.3.2=py36hc1659b7_0 -> numba[version='>=0.28']
# dask-ml==1.0.0=py_0 -> numba
# Package xorg-libxdmcp conflicts for:
# libxcb==1.13=h14c3975_1002 -> xorg-libxdmcp
# Package geos conflicts for:
# cartopy==0.17.0=py36hd759880_1006 -> geos[version='>=3.7.2,<3.7.3.0a0']
# shapely==1.6.4=py36hec07ddf_1006 -> geos[version='>=3.7.2,<3.7.3.0a0']
# Package openssl conflicts for:
# cryptography==2.7=py36h72c5cf5_0 -> openssl[version='>=1.1.1a,<1.1.2a']
# krb5==1.16.3=h05b26f9_1001 -> openssl[version='>=1.1.1a,<1.1.2a']
# qt==5.9.7=h0c104cb_3 -> openssl=1.1
# libssh2==1.8.2=h22169c7_2 -> openssl[version='>=1.1.1a,<1.1.2a']
# samtools==1.9=h8571acd_11 -> openssl[version='>=1.1.1a,<1.1.2a']
# pycurl==7.43.0.2=py36h16ce93b_1 -> openssl[version='>=1.1.1a,<1.1.2a']
# python==3.6.7=h357f687_1005 -> openssl[version='>=1.1.1a,<1.1.2a']
# mysql-connector-c==6.1.11=hd2bbab6_1003 -> openssl[version='>=1.1.1a,<1.1.2a']
# libcurl==7.65.3=hda55be3_0 -> openssl[version='>=1.1.1a,<1.1.2a']
# Package jupyter_core conflicts for:
# nbconvert==5.5.0=py_0 -> jupyter_core
# qtconsole==4.5.2=py_0 -> jupyter_core
# nbformat==4.4.0=py_1 -> jupyter_core
# jupyter_client==5.3.1=py_0 -> jupyter_core
# notebook==6.0.0=py36_0 -> jupyter_core[version='>=4.4.0']
# Package scikit-learn conflicts for:
# dask-ml==1.0.0=py_0 -> scikit-learn[version='>=0.20.0']
# dask-glm==0.1.0=0 -> scikit-learn[version='>=0.18']
# hmmlearn==0.2.1=py36h3010b51_1000 -> scikit-learn[version='>=0.16']
# scikit-allel==1.2.1=py36hb3f55d8_0 -> scikit-learn
# Package freetype conflicts for:
# graphviz==2.38.0=hf68f40c_1011 -> freetype[version='>=2.9.1,<3.0a0']
# fontconfig==2.13.1=h86ecdb6_1001 -> freetype[version='>=2.9.1,<3.0a0']
# matplotlib-base==3.1.1=py36he7580a8_1 -> freetype[version='>=2.9.1,<3.0a0']
# harfbuzz==2.4.0=h9f30f68_2 -> freetype[version='>=2.9.1,<3.0a0']
# pango==1.40.14=he7ab937_1005 -> freetype[version='>=2.9.1,<3.0a0']
# cairo==1.16.0=hfb77d84_1002 -> freetype[version='>=2.9.1,<3.0a0']
# qt==5.9.7=h0c104cb_3 -> freetype[version='>=2.9.1,<3.0a0']
# pillow==6.1.0=py36h6b7be26_1 -> freetype[version='>=2.9.1,<3.0a0']
# Package lz4-c conflicts for:
# zstd==1.4.0=h3b9ef0a_0 -> lz4-c[version='>=1.8.3,<1.8.4.0a0']
# Package dbus conflicts for:
# pyqt==5.9.2=py36hcca6a23_2 -> dbus[version='>=1.13.6,<2.0a0']
# qt==5.9.7=h0c104cb_3 -> dbus[version='>=1.13.6,<2.0a0']
# Package libcblas conflicts for:
# numpy==1.17.0=py36h95a1406_0 -> libcblas[version='>=3.8.0,<4.0a0']
# libblas==3.8.0=11_openblas -> libcblas==3.8.0=11_openblas
# scikit-learn==0.21.3=py36hcdab131_0 -> libcblas[version='>=3.8.0,<4.0a0']
# blas==2.11=openblas -> libcblas==3.8.0=11_openblas
# scipy==1.3.0=py36h921218d_1 -> libcblas[version='>=3.8.0,<4.0a0']
# gsl==2.5=h294904e_0 -> libcblas[version='>=3.8.0,<4.0a0']
# liblapacke==3.8.0=11_openblas -> libcblas==3.8.0=11_openblas
# liblapack==3.8.0=11_openblas -> libcblas==3.8.0=11_openblas
# Package libtool conflicts for:
# graphviz==2.38.0=hf68f40c_1011 -> libtool
# Package toolz conflicts for:
# cytoolz==0.10.0=py36h516909a_0 -> toolz[version='>=0.10.0']
# scikit-image==0.15.0=py36hb3f55d8_2 -> toolz[version='>=0.7.4']
# distributed==2.2.0=py_1 -> toolz[version='>=0.7.4']
# partd==1.0.0=py_0 -> toolz
# dask==2.2.0=py_0 -> toolz[version='>=0.7.3']
# Package jpeg conflicts for:
# pillow==6.1.0=py36h6b7be26_1 -> jpeg[version='>=9c,<10a']
# hdf4==4.2.13=h9a582f1_1002 -> jpeg[version='>=9c,<10a']
# libtiff==4.0.10=h57b8799_1003 -> jpeg[version='>=9c,<10a']
# qt==5.9.7=h0c104cb_3 -> jpeg[version='>=9c,<10a']
# graphviz==2.38.0=hf68f40c_1011 -> jpeg[version='>=9c,<10a']
# libnetcdf==4.6.2=hbdf4f91_1001 -> jpeg[version='>=9c,<10a']
# Package testpath conflicts for:
# nbconvert==5.5.0=py_0 -> testpath
# Package google-resumable-media conflicts for:
# google-cloud-storage==1.17.0=py_0 -> google-resumable-media[version='>=0.3.1']
# Package ncurses conflicts for:
# python==3.6.7=h357f687_1005 -> ncurses[version='>=6.1,<6.2.0a0']
# samtools==1.9=h8571acd_11 -> ncurses[version='>=6.1,<6.2.0a0']
# sqlite==3.29.0=hcee41ef_0 -> ncurses[version='>=6.1,<6.2.0a0']
# libedit==3.1.20170329=hf8c457e_1001 -> ncurses[version='>=6.1,<6.2.0a0']
# readline==8.0=hf8c457e_0 -> ncurses[version='>=6.1,<6.2.0a0']
# Package glib conflicts for:
# gstreamer==1.14.5=h36ae1b5_0 -> glib[version='>=2.58.3,<3.0a0']
# qt==5.9.7=h0c104cb_3 -> glib[version='>=2.58.3,<3.0a0']
# harfbuzz==2.4.0=h9f30f68_2 -> glib[version='>=2.58.3,<3.0a0']
# cairo==1.16.0=hfb77d84_1002 -> glib[version='>=2.58.3,<3.0a0']
# gst-plugins-base==1.14.5=h0935bb2_0 -> glib[version='>=2.58.3,<3.0a0']
# dbus==1.13.6=he372182_0 -> glib[version='>=2.58.3,<3.0a0']
# Package pyopenssl conflicts for:
# urllib3==1.25.3=py36_0 -> pyopenssl[version='>=0.14']
# certipy==0.1.3=py_0 -> pyopenssl
# Package libpng conflicts for:
# freetype==2.10.0=he983fc9_0 -> libpng[version='>=1.6.35,<1.7.0a0']
# cairo==1.16.0=hfb77d84_1002 -> libpng[version='>=1.6.35,<1.7.0a0']
# pango==1.40.14=he7ab937_1005 -> libpng[version='>=1.6.35,<1.7.0a0']
# matplotlib-base==3.1.1=py36he7580a8_1 -> libpng[version='>=1.6.35,<1.7.0a0']
# fontconfig==2.13.1=h86ecdb6_1001 -> libpng[version='>=1.6.35,<1.7.0a0']
# graphviz==2.38.0=hf68f40c_1011 -> libpng[version='>=1.6.35,<1.7.0a0']
# qt==5.9.7=h0c104cb_3 -> libpng[version='>=1.6.35,<1.7.0a0']
# Package pomegranate conflicts for:
# scikit-allel==1.2.1=py36hb3f55d8_0 -> pomegranate
# Package ipykernel conflicts for:
# jupyter==1.0.0=py_2 -> ipykernel
# notebook==6.0.0=py36_0 -> ipykernel
# ipywidgets==7.5.1=py_0 -> ipykernel[version='>=4.5.1']
# qtconsole==4.5.2=py_0 -> ipykernel[version='>=4.1']
# jupyter_console==6.0.0=py_0 -> ipykernel
# Package networkx conflicts for:
# pomegranate==0.11.0=py36h9de70de_0 -> networkx[version='>=2.0']
# snakemake==5.5.4=1 -> networkx[version='>=2.0']
# scikit-image==0.15.0=py36hb3f55d8_2 -> networkx[version='>=1.8']
# Package datrie conflicts for:
# snakemake-minimal==5.5.4=py_1 -> datrie
# Package patsy conflicts for:
# statsmodels==0.10.1=py36hc1659b7_0 -> patsy[version='>=0.4.0']
# Package pyparsing conflicts for:
# matplotlib-base==3.1.1=py36he7580a8_1 -> pyparsing
# packaging==19.0=py_0 -> pyparsing
# svgwrite==1.3.1=py_0 -> pyparsing[version='>=2.0.1']
# Package aiohttp conflicts for:
# aioeasywebdav==2.4.0=py36_1000 -> aiohttp
# Package xorg-xproto conflicts for:
# xorg-libxpm==3.5.12=h14c3975_1002 -> xorg-xproto
# xorg-libxt==1.1.5=h516909a_1003 -> xorg-xproto
# xorg-libx11==1.6.8=h516909a_0 -> xorg-xproto
# Package jinja2 conflicts for:
# nbconvert==5.5.0=py_0 -> jinja2
# snakemake==5.5.4=1 -> jinja2
# bokeh==1.3.2=py36_0 -> jinja2[version='>=2.7']
# jupyterhub==1.0.0=py36_0 -> jinja2
# notebook==6.0.0=py36_0 -> jinja2
# intake==0.5.2=py_0 -> jinja2
# branca==0.3.1=py_0 -> jinja2
# Package bleach conflicts for:
# nbconvert==5.5.0=py_0 -> bleach
# Package protobuf conflicts for:
# googleapis-common-protos==1.6.0=py36_0 -> protobuf
# google-api-core==1.14.2=py36_0 -> protobuf[version='>=3.4.0']
# Package attrs conflicts for:
# jsonschema==3.0.2=py36_0 -> attrs[version='>=17.4.0']
# aiohttp==3.5.4=py36h14c3975_0 -> attrs[version='>=17.3.0']
# Package async-timeout conflicts for:
# aiohttp==3.5.4=py36h14c3975_0 -> async-timeout[version='>=3.0,<4.0']
# Package ipywidgets conflicts for:
# jupyter==1.0.0=py_2 -> ipywidgets
# bqplot==0.11.6=py_0 -> ipywidgets[version='>=7.0.0,<8.0']
# ipyleaflet==0.11.1=py36_1 -> ipywidgets[version='>=7.5.0,<8.0.0']
# Package libxml2 conflicts for:
# fontconfig==2.13.1=h86ecdb6_1001 -> libxml2[version='>=2.9.9,<2.10.0a0']
# qt==5.9.7=h0c104cb_3 -> libxml2[version='>=2.9.9,<2.10.0a0']
# Package jupyter_client conflicts for:
# notebook==6.0.0=py36_0 -> jupyter_client[version='>=5.3.1']
# jupyter_console==6.0.0=py_0 -> jupyter_client
# qtconsole==4.5.2=py_0 -> jupyter_client[version='>=4.1']
# ipykernel==5.1.1=py36h5ca1d4c_0 -> jupyter_client
# Package urllib3 conflicts for:
# python-kubernetes==10.0.0=py36_0 -> urllib3[version='>=1.23']
# requests==2.22.0=py36_1 -> urllib3[version='>=1.21.1,<1.26,!=1.25.0,!=1.25.1']
# botocore==1.12.202=py_0 -> urllib3[version='>=1.20,<1.26']
# Package pandas conflicts for:
# snakemake==5.5.4=1 -> pandas
# scikit-allel==1.2.1=py36hb3f55d8_0 -> pandas
# xarray==0.12.3=py_0 -> pandas[version='>=0.19.2']
# seaborn==0.9.0=py_1 -> pandas[version='>=0.14.0']
# fastparquet==0.3.2=py36hc1659b7_0 -> pandas[version='>=0.19']
# dask-ml==1.0.0=py_0 -> pandas[version='>=0.23.0']
# dask==2.2.0=py_0 -> pandas[version='>=0.21.0']
# bcolz==1.2.1=py36h637b7d7_1001 -> pandas
# bqplot==0.11.6=py_0 -> pandas
# statsmodels==0.10.1=py36hc1659b7_0 -> pandas[version='>=0.14']
# Package pyqt conflicts for:
# matplotlib==3.1.1=py36_1 -> pyqt
# qtconsole==4.5.2=py_0 -> pyqt
# Package mistune conflicts for:
# nbconvert==5.5.0=py_0 -> mistune[version='>=0.8.1']
# Package intake conflicts for:
# intake-xarray==0.3.1=py_0 -> intake[version='>=0.5.2']
# Package gst-plugins-base conflicts for:
# qt==5.9.7=h0c104cb_3 -> gst-plugins-base[version='>=1.14.4,<1.15.0a0']
# Package backcall conflicts for:
# ipython==7.7.0=py36h5ca1d4c_0 -> backcall
# Package cloudpickle conflicts for:
# distributed==2.2.0=py_1 -> cloudpickle[version='>=0.2.2']
# dask==2.2.0=py_0 -> cloudpickle[version='>=0.2.1']
# scikit-image==0.15.0=py36hb3f55d8_2 -> cloudpickle[version='>=0.2.1']
# Package et_xmlfile conflicts for:
# openpyxl==2.6.2=py_0 -> et_xmlfile
# Package svgwrite conflicts for:
# tskit==0.1.5=py36hd352d35_0 -> svgwrite
# msprime==0.7.3=py36heade8f8_0 -> svgwrite
# Package botocore conflicts for:
# boto3==1.9.202=py_0 -> botocore[version='>=1.12.202,<1.13.0']
# s3transfer==0.2.1=py36_0 -> botocore[version='>=1.12.36,<2.0.0']
# Package readline conflicts for:
# sqlite==3.29.0=hcee41ef_0 -> readline[version='>=8.0,<9.0a0']
# python==3.6.7=h357f687_1005 -> readline[version='>=8.0,<9.0a0']
# Package blosc conflicts for:
# pytables==3.5.2=py36ha1aa75f_0 -> blosc[version='>=1.16.3,<2.0a0']
# Package wrapt conflicts for:
# snakemake-minimal==5.5.4=py_1 -> wrapt
# Package jmespath conflicts for:
# botocore==1.12.202=py_0 -> jmespath[version='>=0.7.1,<1.0.0']
# boto3==1.9.202=py_0 -> jmespath[version='>=0.7.1,<1.0.0']
# Package dask-glm conflicts for:
# dask-ml==1.0.0=py_0 -> dask-glm
# Package pyproj conflicts for:
# owslib==0.18.0=py_0 -> pyproj
# Package pixman conflicts for:
# cairo==1.16.0=hfb77d84_1002 -> pixman[version='>=0.38.0,<0.39.0a0']
# Package idna conflicts for:
# cryptography==2.7=py36h72c5cf5_0 -> idna[version='>=2.1']
# requests==2.22.0=py36_1 -> idna[version='>=2.5,<2.9']
# urllib3==1.25.3=py36_0 -> idna[version='>=2.0.0']
# yarl==1.3.0=py36h14c3975_1000 -> idna[version='>=2.0']
# idna_ssl==1.1.0=py36_1000 -> idna[version='>=2']
# Package zstd conflicts for:
# libtiff==4.0.10=h57b8799_1003 -> zstd[version='>=1.4.0,<1.4.1.0a0']
# Package mako conflicts for:
# alembic==1.0.11=py_0 -> mako
# Package msgpack-python conflicts for:
# intake==0.5.2=py_0 -> msgpack-python
# distributed==2.2.0=py_1 -> msgpack-python
# msgpack-numpy==0.4.4.3=py_0 -> msgpack-python[version='>=0.5.2']
# numcodecs==0.6.3=py36hf484d3e_0 -> msgpack-python
# Package cytoolz conflicts for:
# scikit-image==0.15.0=py36hb3f55d8_2 -> cytoolz[version='>=0.7.3']
# dask==2.2.0=py_0 -> cytoolz[version='>=0.7.3']
# distributed==2.2.0=py_1 -> cytoolz[version='>=0.7.4']
# Package rsa conflicts for:
# google-auth==1.6.3=py_0 -> rsa[version='>=3.1.4,<4dev']
# Package hdf5 conflicts for:
# pytables==3.5.2=py36ha1aa75f_0 -> hdf5[version='>=1.10.4,<1.10.5.0a0']
# h5py==2.9.0=nompi_py36hcafd542_1103 -> hdf5[version='>=1.10.4,<1.10.5.0a0']
# netcdf4==1.5.1.2=py36had58050_0 -> hdf5[version='>=1.10.4,<1.10.5.0a0']
# libnetcdf==4.6.2=hbdf4f91_1001 -> hdf5[version='>=1.10.4,<1.10.5.0a0']
# Package xorg-kbproto conflicts for:
# xorg-libxt==1.1.5=h516909a_1003 -> xorg-kbproto
# xorg-libx11==1.6.8=h516909a_0 -> xorg-kbproto
# Package nbformat conflicts for:
# nbconvert==5.5.0=py_0 -> nbformat[version='>=4.4']
# notebook==6.0.0=py36_0 -> nbformat
# ipywidgets==7.5.1=py_0 -> nbformat[version='>=4.2.0']
# Package libxcb conflicts for:
# cairo==1.16.0=hfb77d84_1002 -> libxcb
# qt==5.9.7=h0c104cb_3 -> libxcb
# xorg-libx11==1.6.8=h516909a_0 -> libxcb=1
# graphviz==2.38.0=hf68f40c_1011 -> libxcb
# Package webencodings conflicts for:
# bleach==3.1.0=py_0 -> webencodings
# Package python-irodsclient conflicts for:
# snakemake==5.5.4=1 -> python-irodsclient
# Package distributed conflicts for:
# dask-ml==1.0.0=py_0 -> distributed[version='>=1.25.0']
# dask==2.2.0=py_0 -> distributed[version='>=2.2.0']
# dask-kubernetes==0.9.1=py_0 -> distributed[version='>=1.22.0']
# Package pyzmq conflicts for:
# jupyter_client==5.3.1=py_0 -> pyzmq[version='>=13']
# notebook==6.0.0=py36_0 -> pyzmq[version='>=17']
# Package parso conflicts for:
# jedi==0.14.1=py36_0 -> parso[version='>=0.5.0']
# Package bcrypt conflicts for:
# paramiko==2.6.0=py36_0 -> bcrypt[version='>=3.1.3']
# Package proj4 conflicts for:
# pyproj==1.9.6=py36h516909a_1002 -> proj4[version='>=5.2,<6,>=5.2.0,<5.2.1.0a0']
# cartopy==0.17.0=py36hd759880_1006 -> proj4[version='5.2.0.*,>=5.2.0,<5.2.1.0a0']
# Package xorg-libxpm conflicts for:
# graphviz==2.38.0=hf68f40c_1011 -> xorg-libxpm
# Package fasteners conflicts for:
# zarr==2.3.2=py36_0 -> fasteners
# Package async_generator conflicts for:
# jupyterhub==1.0.0=py36_0 -> async_generator[version='>=1.8']
# Package pyyaml conflicts for:
# python-kubernetes==10.0.0=py36_0 -> pyyaml[version='>=3.12']
# bokeh==1.3.2=py36_0 -> pyyaml[version='>=3.10']
# snakemake-minimal==5.5.4=py_1 -> pyyaml
# distributed==2.2.0=py_1 -> pyyaml
# pomegranate==0.11.0=py36h9de70de_0 -> pyyaml
# Package ptyprocess conflicts for:
# terminado==0.8.2=py36_0 -> ptyprocess
# pexpect==4.7.0=py36_0 -> ptyprocess[version='>=0.5']
# Package libssh2 conflicts for:
# libcurl==7.65.3=hda55be3_0 -> libssh2[version='>=1.8.2,<1.9.0a0']
# curl==7.65.3=hf8cf82a_0 -> libssh2[version='>=1.8.2,<1.9.0a0']
# Package lzo conflicts for:
# pytables==3.5.2=py36ha1aa75f_0 -> lzo[version='>=2.10,<3.0a0']
# Package requests-oauthlib conflicts for:
# python-kubernetes==10.0.0=py36_0 -> requests-oauthlib
# google-auth-oauthlib==0.4.0=py_0 -> requests-oauthlib[version='>=0.7.0']
# Package kiwisolver conflicts for:
# matplotlib-base==3.1.1=py36he7580a8_1 -> kiwisolver
# Package gettext conflicts for:
# glib==2.58.3=h6f030ca_1002 -> gettext[version='>=0.19.8.1,<1.0a0']
# xorg-libxpm==3.5.12=h14c3975_1002 -> gettext[version='>=0.19.8.1,<1.0a0']
# Package tbb conflicts for:
# numba==0.45.1=py36hb3f55d8_0 -> tbb[version='>=2018.0.5']
# Package google-cloud-core conflicts for:
# google-cloud-storage==1.17.0=py_0 -> google-cloud-core[version='>=1.0.0']
# Package uncertainties conflicts for:
# lmfit==0.9.13=pyh24bf2e0_0 -> uncertainties[version='>=3.0']
# Package packaging conflicts for:
# dask-ml==1.0.0=py_0 -> packaging
# bokeh==1.3.2=py36_0 -> packaging[version='>=16.8']
# Package libtiff conflicts for:
# graphviz==2.38.0=hf68f40c_1011 -> libtiff[version='>=4.0.9,<5.0a0']
# pillow==6.1.0=py36h6b7be26_1 -> libtiff[version='>=4.0.10,<5.0a0']
# Package ipython_genutils conflicts for:
# nbformat==4.4.0=py_1 -> ipython_genutils
# traitlets==4.3.2=py36_1000 -> ipython_genutils
# notebook==6.0.0=py36_0 -> ipython_genutils
# Package graphviz conflicts for:
# python-graphviz==0.11.1=py_1 -> graphviz
# pygraphviz==1.5=py36h516909a_1001 -> graphviz=2.38
# Package appdirs conflicts for:
# snakemake-minimal==5.5.4=py_1 -> appdirs
# intake==0.5.2=py_0 -> appdirs
# Package wheel conflicts for:
# pip==19.2.1=py36_0 -> wheel
# Package pyjwt conflicts for:
# oauthlib==3.0.1=py_0 -> pyjwt[version='>=1.0.0']
# adal==1.2.2=py_0 -> pyjwt[version='>=1.0.0']
# Package entrypoints conflicts for:
# intake==0.5.2=py_0 -> entrypoints
# nbconvert==5.5.0=py_0 -> entrypoints[version='>=0.2.2']
# jupyterhub==1.0.0=py36_0 -> entrypoints
# Package blas conflicts for:
# libcblas==3.8.0=11_openblas -> blas=[build=openblas]
# liblapacke==3.8.0=11_openblas -> blas=[build=openblas]
# libblas==3.8.0=11_openblas -> blas=[build=openblas]
# liblapack==3.8.0=11_openblas -> blas=[build=openblas]
# Package ftputil conflicts for:
# snakemake==5.5.4=1 -> ftputil[version='>=3.2']
# Package asciitree conflicts for:
# zarr==2.3.2=py36_0 -> asciitree
# Package python-kubernetes conflicts for:
# dask-kubernetes==0.9.1=py_0 -> python-kubernetes[version='>=9']
# Package cachetools conflicts for:
# google-auth==1.6.3=py_0 -> cachetools[version='>=2.0.0,<3dev']
# Package pango conflicts for:
# graphviz==2.38.0=hf68f40c_1011 -> pango[version='>=1.40.14,<1.41.0a0']
# Package expat conflicts for:
# qt==5.9.7=h0c104cb_3 -> expat[version='>=2.2.5,<2.3.0a0']
# graphviz==2.38.0=hf68f40c_1011 -> expat[version='>=2.2.5,<2.3.0a0']
# dbus==1.13.6=he372182_0 -> expat[version='>=2.2.5,<2.3.0a0']
# Package xorg-libxext conflicts for:
# xorg-libxpm==3.5.12=h14c3975_1002 -> xorg-libxext=1.3
# cairo==1.16.0=hfb77d84_1002 -> xorg-libxext
# Package icu conflicts for:
# fontconfig==2.13.1=h86ecdb6_1001 -> icu[version='>=64.2,<65.0a0']
# qt==5.9.7=h0c104cb_3 -> icu[version='>=64.2,<65.0a0']
# libxml2==2.9.9=hee79883_2 -> icu[version='>=64.2,<65.0a0']
# harfbuzz==2.4.0=h9f30f68_2 -> icu[version='>=64.2,<65.0a0']
# matplotlib-base==3.1.1=py36he7580a8_1 -> icu[version='>=64.2,<65.0a0']
# cairo==1.16.0=hfb77d84_1002 -> icu[version='>=64.2,<65.0a0']
# Package pickleshare conflicts for:
# ipython==7.7.0=py36h5ca1d4c_0 -> pickleshare
# Package multipledispatch conflicts for:
# dask-ml==1.0.0=py_0 -> multipledispatch[version='>=0.4.9']
# dask-glm==0.1.0=0 -> multipledispatch[version='>=0.4.9']
# Package s3transfer conflicts for:
# boto3==1.9.202=py_0 -> s3transfer[version='>=0.2.0,<0.3.0']
# Package nbconvert conflicts for:
# notebook==6.0.0=py36_0 -> nbconvert
# jupyter==1.0.0=py_2 -> nbconvert
# Package xmlrunner conflicts for:
# python-irodsclient==0.7.0=py_0 -> xmlrunner[version='>=1.7.7']
# Package pyepsg conflicts for:
# cartopy==0.17.0=py36hd759880_1006 -> pyepsg
# Package multidict conflicts for:
# yarl==1.3.0=py36h14c3975_1000 -> multidict[version='>=4.0']
# aiohttp==3.5.4=py36h14c3975_0 -> multidict[version='>=4.0,<5.0']
# Package libedit conflicts for:
# krb5==1.16.3=h05b26f9_1001 -> libedit[version='>=3.1.20170329,<4.0a0']
# Package paramiko conflicts for:
# pysftp==0.2.9=py_1 -> paramiko[version='>=1.17.0']
# Package libdeflate conflicts for:
# htslib==1.9=ha228f0b_7 -> libdeflate[version='>=1.0,<1.1.0a0']
# pysam==0.15.3=py36h5ad169c_0 -> libdeflate[version='>=1.0,<1.1.0a0']
# bcftools==1.9=ha228f0b_4 -> libdeflate[version='>=1.0,<1.1.0a0']
# samtools==1.9=h8571acd_11 -> libdeflate[version='>=1.0,<1.1.0a0']
# Package param conflicts for:
# holoviews==1.12.4=py_0 -> param[version='>=1.9.0,<2.0']
# pyviz_comms==0.7.2=py_0 -> param
# Package typing_extensions conflicts for:
# aiohttp==3.5.4=py36h14c3975_0 -> typing_extensions[version='>=3.6.5']
# Package pygraphviz conflicts for:
# snakemake==5.5.4=1 -> pygraphviz
# Package joblib conflicts for:
# scikit-learn==0.21.3=py36hcdab131_0 -> joblib[version='>=0.11']
# pomegranate==0.11.0=py36h9de70de_0 -> joblib[version='>=0.9.0b4']
# Package xorg-libxrender conflicts for:
# cairo==1.16.0=hfb77d84_1002 -> xorg-libxrender
# graphviz==2.38.0=hf68f40c_1011 -> xorg-libxrender
# Package olefile conflicts for:
# pillow==6.1.0=py36h6b7be26_1 -> olefile
# Package pyrsistent conflicts for:
# jsonschema==3.0.2=py36_0 -> pyrsistent[version='>=0.14.0']
# Package cryptography conflicts for:
# oauthlib==3.0.1=py_0 -> cryptography
# pyjwt==1.7.1=py_0 -> cryptography[version='>=1.4']
# paramiko==2.6.0=py36_0 -> cryptography[version='>=2.5']
# pyopenssl==19.0.0=py36_0 -> cryptography[version='>=2.2.1']
# urllib3==1.25.3=py36_0 -> cryptography[version='>=1.3.4']
# adal==1.2.2=py_0 -> cryptography[version='>=1.1.0']
# Package _libgcc_mutex conflicts for:
# libgcc-ng==9.1.0=hdf63c60_0 -> _libgcc_mutex=[build=main]
# Package htslib conflicts for:
# pysam==0.15.3=py36h5ad169c_0 -> htslib[version='>=1.9,<1.10.0a0']
# Package pynacl conflicts for:
# paramiko==2.6.0=py36_0 -> pynacl[version='>=1.0.1']
# Package cairo conflicts for:
# pango==1.40.14=he7ab937_1005 -> cairo[version='>=1.16.0,<1.17.0a0']
# harfbuzz==2.4.0=h9f30f68_2 -> cairo[version='>=1.16.0,<1.17.0a0']
# graphviz==2.38.0=hf68f40c_1011 -> cairo[version='>=1.16.0,<1.17.0a0']
# Package numcodecs conflicts for:
# scikit-allel==1.2.1=py36hb3f55d8_0 -> numcodecs
# zarr==2.3.2=py36_0 -> numcodecs[version='>=0.6.2']
# Package owslib conflicts for:
# cartopy==0.17.0=py36hd759880_1006 -> owslib
# Package yaml conflicts for:
# pyyaml==5.1.2=py36h516909a_0 -> yaml[version='>=0.1.7,<0.2.0a0']
# Package qtconsole conflicts for:
# jupyter==1.0.0=py_2 -> qtconsole
# Package sip conflicts for:
# pyqt==5.9.2=py36hcca6a23_2 -> sip[version='>=4.19.4,<=4.19.8']
# Package widgetsnbextension conflicts for:
# ipywidgets==7.5.1=py_0 -> widgetsnbextension[version='>=3.5.0,<3.6.0']
# Package thrift conflicts for:
# fastparquet==0.3.2=py36hc1659b7_0 -> thrift=0.11
# Package chardet conflicts for:
# requests==2.22.0=py36_1 -> chardet[version='>=3.0.2,<3.1.0']
# aiohttp==3.5.4=py36h14c3975_0 -> chardet[version='>=2.0,<4.0']
# Package fontconfig conflicts for:
# cairo==1.16.0=hfb77d84_1002 -> fontconfig[version='>=2.13.1,<3.0a0']
# qt==5.9.7=h0c104cb_3 -> fontconfig[version='>=2.13.1,<3.0a0']
# pango==1.40.14=he7ab937_1005 -> fontconfig[version='>=2.13.1,<3.0a0']
# Package netcdf4 conflicts for:
# intake-xarray==0.3.1=py_0 -> netcdf4
# Package terminado conflicts for:
# notebook==6.0.0=py36_0 -> terminado[version='>=0.8.1']
# Package blinker conflicts for:
# oauthlib==3.0.1=py_0 -> blinker
# Package idna_ssl conflicts for:
# aiohttp==3.5.4=py36h14c3975_0 -> idna_ssl[version='>=1,<2']
# Package adal conflicts for:
# python-kubernetes==10.0.0=py36_0 -> adal[version='>=1.0.2']
# Package google-api-core conflicts for:
# google-cloud-storage==1.17.0=py_0 -> google-api-core[version='>=1.6.0']
# google-cloud-core==1.0.3=py_0 -> google-api-core[version='>=1.14.0,<2.0.0dev']
# Package json5 conflicts for:
# jupyterlab_server==1.0.0=py_1 -> json5
# Package pysam conflicts for:
# pysamstats==1.1.2=py36h84994c4_3 -> pysam[version='>=0.15.2,<0.16.0a0']
# Package pytables conflicts for:
# pysamstats==1.1.2=py36h84994c4_3 -> pytables
# bcolz==1.2.1=py36h637b7d7_1001 -> pytables
# Package sqlite conflicts for:
# qt==5.9.7=h0c104cb_3 -> sqlite[version='>=3.29.0,<4.0a0']
# python==3.6.7=h357f687_1005 -> sqlite[version='>=3.28.0,<4.0a0']
# Package prometheus_client conflicts for:
# notebook==6.0.0=py36_0 -> prometheus_client
# jupyterhub==1.0.0=py36_0 -> prometheus_client[version='>=0.0.21']
# Package libnetcdf conflicts for:
# netcdf4==1.5.1.2=py36had58050_0 -> libnetcdf[version='>=4.6.2,<4.6.3.0a0']
# Package certipy conflicts for:
# jupyterhub==1.0.0=py36_0 -> certipy[version='>=0.1.2']
# Package wcwidth conflicts for:
# prompt_toolkit==2.0.9=py_0 -> wcwidth
# Package pamela conflicts for:
# jupyterhub==1.0.0=py36_0 -> pamela
# Package mysql-connector-c conflicts for:
# mysqlclient==1.3.13=py36_1000 -> mysql-connector-c
# Package python-editor conflicts for:
# alembic==1.0.11=py_0 -> python-editor[version='>=0.3']
# Package send2trash conflicts for:
# notebook==6.0.0=py36_0 -> send2trash
# Package tskit conflicts for:
# msprime==0.7.3=py36heade8f8_0 -> tskit
# Package bcolz conflicts for:
# scikit-allel==1.2.1=py36hb3f55d8_0 -> bcolz
# Package asn1crypto conflicts for:
# cryptography==2.7=py36h72c5cf5_0 -> asn1crypto[version='>=0.21.0']
# Package xorg-libice conflicts for:
# cairo==1.16.0=hfb77d84_1002 -> xorg-libice
# xorg-libxt==1.1.5=h516909a_1003 -> xorg-libice=1.0
# xorg-libsm==1.2.3=h84519dc_1000 -> xorg-libice=1.0
# Package certifi conflicts for:
# requests==2.22.0=py36_1 -> certifi[version='>=2017.4.17']
# urllib3==1.25.3=py36_0 -> certifi
# setuptools==41.0.1=py36_0 -> certifi[version='>=2016.09']
# python-kubernetes==10.0.0=py36_0 -> certifi[version='>=14.05.14']
# Package defusedxml conflicts for:
# nbconvert==5.5.0=py_0 -> defusedxml
# Package xarray conflicts for:
# ipyleaflet==0.11.1=py36_1 -> xarray[version='>=0.10.0']
# intake-xarray==0.3.1=py_0 -> xarray[version='>=0.12.0']
# Package nodejs conflicts for:
# configurable-http-proxy==4.1.0=node11_1 -> nodejs=11
# Package pyasn1 conflicts for:
# rsa==3.4.2=py_1 -> pyasn1[version='>=0.1.3']
# pyasn1-modules==0.2.6=py_0 -> pyasn1[version='>=0.4.1,<0.5.0']
# Package heapdict conflicts for:
# zict==1.0.0=py_0 -> heapdict
# Package libcurl conflicts for:
# pycurl==7.43.0.2=py36h16ce93b_1 -> libcurl[version='>=7.64.1,<8.0a0']
# curl==7.65.3=hf8cf82a_0 -> libcurl==7.65.3=hda55be3_0
# Package imageio conflicts for:
# scikit-image==0.15.0=py36hb3f55d8_2 -> imageio[version='>=2.1.0']
# Package branca conflicts for:
# ipyleaflet==0.11.1=py36_1 -> branca[version='>=0.3.1,<0.4.0']
# Package pycparser conflicts for:
# cffi==1.12.3=py36h8022711_0 -> pycparser
# Package dropbox conflicts for:
# snakemake==5.5.4=1 -> dropbox[version='>=7.2.1']
# Package ptable conflicts for:
# prettytable==0.7.2=py_3 -> ptable[version='>=9999']
# Package qt conflicts for:
# pyqt==5.9.2=py36hcca6a23_2 -> qt[version='5.9.*,>=5.9.7,<5.10.0a0']
# Package gstreamer conflicts for:
# qt==5.9.7=h0c104cb_3 -> gstreamer[version='>=1.14.4,<1.15.0a0']
# gst-plugins-base==1.14.5=h0935bb2_0 -> gstreamer[version='>=1.14.5,<2.0a0']
# Package seaborn conflicts for:
# scikit-allel==1.2.1=py36hb3f55d8_0 -> seaborn
# Package ruamel.yaml conflicts for:
# intake==0.5.2=py_0 -> ruamel.yaml[version='>=0.15.0']
# Package pykdtree conflicts for:
# cartopy==0.17.0=py36hd759880_1006 -> pykdtree
# Package openblas conflicts for:
# libopenblas==0.3.6=h6e990d7_6 -> openblas[version='>=0.3.6,<0.3.7.0a0']
# Package aioeasywebdav conflicts for:
# snakemake==5.5.4=1 -> aioeasywebdav
# Package statsmodels conflicts for:
# seaborn==0.9.0=py_1 -> statsmodels[version='>=0.5.0']
# Package docutils conflicts for:
# botocore==1.12.202=py_0 -> docutils[version='>=0.10,<0.15']
# snakemake-minimal==5.5.4=py_1 -> docutils
# Package websocket-client conflicts for:
# python-kubernetes==10.0.0=py36_0 -> websocket-client[version='>=0.32.0,!=0.40.0,!=0.41.*,!=0.42.*']
# Package click conflicts for:
# distributed==2.2.0=py_1 -> click[version='>=6.6']
# Package pyviz_comms conflicts for:
# holoviews==1.12.4=py_0 -> pyviz_comms[version='>=0.7.2']
# Package pyshp conflicts for:
# cartopy==0.17.0=py36hd759880_1006 -> pyshp
# Package bcftools conflicts for:
# pysam==0.15.3=py36h5ad169c_0 -> bcftools=1.9
# Package pthread-stubs conflicts for:
# libxcb==1.13=h14c3975_1002 -> pthread-stubs
# Package configargparse conflicts for:
# snakemake-minimal==5.5.4=py_1 -> configargparse
# Package filechunkio conflicts for:
# snakemake==5.5.4=1 -> filechunkio[version='>=1.6']
# Package python-snappy conflicts for:
# intake==0.5.2=py_0 -> python-snappy
# Package llvmlite conflicts for:
# numba==0.45.1=py36hb3f55d8_0 -> llvmlite[version='>=0.29.0,>=0.29.0,<0.30.0a0']
# Package ruamel conflicts for:
# ruamel.yaml==0.16.0=py36h516909a_0 -> ruamel
# Package ratelimiter conflicts for:
# snakemake-minimal==5.5.4=py_1 -> ratelimiter
# Package hdf4 conflicts for:
# libnetcdf==4.6.2=hbdf4f91_1001 -> hdf4[version='>=4.2.13,<4.3.0a0']
# Package prompt_toolkit conflicts for:
# ipython==7.7.0=py36h5ca1d4c_0 -> prompt_toolkit[version='>=2.0.0']
# jupyter_console==6.0.0=py_0 -> prompt_toolkit[version='>=2.0.0,<2.1.0']
# Package gitpython conflicts for:
# snakemake-minimal==5.5.4=py_1 -> gitpython
# Package libgdal conflicts for:
# gdal -> libgdal[version='2.4.1|2.4.2|2.4.2|2.4.2|2.4.2|3.0.1|3.0.1',build='h2bea7cd_7|hbef8c27_4|h182c168_7|h04a3d72_6|heae24aa_8|hc4f5fd6_10|ha50d65d_9|h524de44_5|hf47eb90_8']
# Package cycler conflicts for:
# matplotlib-base==3.1.1=py36he7580a8_1 -> cycler[version='>=0.10']
# Package pcre conflicts for:
# glib==2.58.3=h6f030ca_1002 -> pcre[version='>=8.41,<9.0a0']
# gstreamer==1.14.5=h36ae1b5_0 -> pcre[version='>=8.41,<9.0a0']
# Package krb5 conflicts for:
# curl==7.65.3=hf8cf82a_0 -> krb5[version='>=1.16.3,<1.17.0a0']
# libcurl==7.65.3=hda55be3_0 -> krb5[version='>=1.16.3,<1.17.0a0']
# Package googleapis-common-protos conflicts for:
# google-api-core==1.14.2=py36_0 -> googleapis-common-protos[version='>=1.6.0,<2.0dev']
# Package partd conflicts for:
# dask==2.2.0=py_0 -> partd[version='>=0.3.10']
# Package monotonic conflicts for:
# fasteners==0.14.1=py_3 -> monotonic[version='>=0.1']
# Package zict conflicts for:
# distributed==2.2.0=py_1 -> zict[version='>=0.1.3']
# Package pycurl conflicts for:
# jupyterhub==1.0.0=py36_0 -> pycurl
# Package configurable-http-proxy conflicts for:
# jupyterhub==1.0.0=py36_0 -> configurable-http-proxy
# Package graphite2 conflicts for:
# harfbuzz==2.4.0=h9f30f68_2 -> graphite2
# Package alembic conflicts for:
# jupyterhub==1.0.0=py36_0 -> alembic
# Package samtools conflicts for:
# pysam==0.15.3=py36h5ad169c_0 -> samtools=1.9
# Package gitdb2 conflicts for:
# gitpython==2.1.13=py_0 -> gitdb2
# Package pysftp conflicts for:
# snakemake==5.5.4=1 -> pysftp[version='>=0.2.8']
# Package jdcal conflicts for:
# openpyxl==2.6.2=py_0 -> jdcal
# Package xorg-libxau conflicts for:
# libxcb==1.13=h14c3975_1002 -> xorg-libxau
# Package shapely conflicts for:
# cartopy==0.17.0=py36hd759880_1006 -> shapely
# Package harfbuzz conflicts for:
# pango==1.40.14=he7ab937_1005 -> harfbuzz[version='>=2.4.0,<3.0a0']
# Package zeromq conflicts for:
# pyzmq==18.0.2=py36h1768529_2 -> zeromq[version='>=4.3.2,<4.4.0a0']
# Package locket conflicts for:
# partd==1.0.0=py_0 -> locket
# Package pandocfilters conflicts for:
# nbconvert==5.5.0=py_0 -> pandocfilters[version='>=1.4.1']
# Package pip conflicts for:
# python==3.6.7=h357f687_1005 -> pip
# Package ca-certificates conflicts for:
# openssl -> ca-certificates
# Package pexpect conflicts for:
# ipython==7.7.0=py36h5ca1d4c_0 -> pexpect
# Note that strict channel priority may have removed packages required for satisfiability.

# %%
import os
import gdal
import ogr
import osr
import gdalnumeric
import gdalconst
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-74d2cdeb765d> in <module>
#       1 import os
# ----> 2 import gdal
#       3 import ogr
#       4 import osr
#       5 import gdalnumeric
#
# ModuleNotFoundError: No module named 'gdal'
